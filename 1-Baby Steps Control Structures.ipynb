# %% [markdown]
# ## Print Statement ##

# %%
print("Welcome to Assignemnet-1")
# Out:
# Welcome to Assignemnet-1

# %% [markdown]
# ## Calaculation ##

# %%
num1 = 10
num2 = 30
add = num1 + num2
print("Num1 =",num1, "\nNum2 =",num2, "\nAdd  =",add)
# Out:
# Num1 = 10
# Num2 = 30
# Add  = 40

# %% [markdown]
# ## Body Mass Index ##

# %%
weight = int(input("Enter you Weight in Kilogram :"))
height = float(input("Enter you Height in Meter :"))
bmi = weight / (height ** 2)
print(f"Your BMI is: {bmi:.1f}")
if bmi < 18.5:
    print("Your are Underweight")
elif bmi >= 18.5 and bmi <= 24.9:
    print("Your are Healthy Weight")
elif bmi >= 25 and bmi <= 29.9:
    print("Your are Overweight")
else:
    print("Your are Obese")
# Out:
# Enter you Weight in Kilogram : 30
# Enter you Height in Meter : 1.2
# Your BMI is: 20.8
# Your are Healthy Weight
