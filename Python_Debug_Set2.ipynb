# %%
#1.Find the error in the following Python code:
"""
import math
print(Math.sqrt(16))

Answer : library name mentioned in import and in print statement differes.
"""

#. Corrected 

import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:
"""
def my_function():
    x += 5
    print(x)

x = 10
my_function()

Answer - x is not a Global variable , its defined inside the function and treated a local variable, to get the code work we can we can pass x as a parameter.
"""
#. Corrected code 
def my_function(x):
    x += 5
    print(x)

x = 10
my_function(x)
# Out:
# 15

# %%
#3.
"""
x = 5
if x = 10:
    print("x is 10")

Answer : insted of comparison operatoe "==" assignment operator is assiged to x. So no oput put will be generated.
"""

#. Corrected code
x = 5
if x == 10:
    print("x is 10")
else:
    print("x is not 10")
# Out:
# x is not 10

# %%
#4.
"""
numbers = [5, 3, 8, 2]
print(numbers.sort())
Answer : print(numbers.sort()) we are priniting the return value which is none. First sort the list then print
"""
#. Corrected Code
numbers = [5, 3, 8, 2]
numbers.sort()
print(numbers)
# Out:
# [2, 3, 5, 8]

# %%
#5.
"""
def square(n):
    n * n
print(square(4))
Answer - No return or print function so none only will be returned.
"""
#. Corrected Code
def square(n):
    sq_rt = n * n
    return sq_rt
print(square(4))
# Out:
# 16

# %%
#6.
"""
my_tuple = (1, 2, 3)
my_tuple[1] = 5
Answer = 'tuple' are immutable that cannot be changed after creation. Use list , List are mutable and can be altered after creation also.
"""
my_tuple = [1, 2, 3]
my_tuple[1] = 5
print(my_tuple)
# Out:
# [1, 5, 3]

# %%
#7.
"""
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name))

Answer = formatting string is not given.
"""

#. Corrected Code
name = "Alice"
age = 25
print (f"My name is {name} and I am {age} years old")
# Out:
# My name is Alice and I am 25 years old

# %%
#8.

"""
a = [1, 2, 3]
b = [1, 2, 3]
if a is b:
    print("Lists are equal")

Answer - instead of comparision operator "is" is given.
"""

#. Corrected
a = [1, 2, 3]
b = [1, 2, 3]
if a == b:
    print("Lists are equal")
# Out:
# Lists are equal

# %%
#9.
"""
for i in range(5, 1):
    print(i)

Answer = Start is greater than stop and the sequence is empty.
"""

#. Corrected Code
for i in range(1, 5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
#10.
"""
student = {"name": "John", "age": 20}
print(student[name])

Answer = In the dictonary key must be accessed using string , but during print it called without string.
"""

#. Corrected Code
student = {"name": "John", "age": 20}
print(student["name"])
# Out:
# John
