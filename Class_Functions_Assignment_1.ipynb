# %% [markdown]
# ## Create a Class and function and List out items in the list

# %%
class SubfieldsInAI():
    def Subfields():
        hope_AI_topic = ['Machine Learning','Neural Networks','Vision','Robotics','Speech Processing','Natural Language Processing']
        print("Sub-fields in AI are:")
        for i in hope_AI_topic:
            print(i)      
SubfieldsInAI.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %% [markdown]
# ## Create a Class and function that checks whether the given number is Odd or Even

# %%
class OddEven():
    def OddEven():
        oddeven = int(input("Enter the Number to check, the given Number is Odd or Even :"))
        if oddeven % 2 == 0:
            print(f'{oddeven} is a Even Number')
        else:
            print(f'{oddeven} is a Odd Number')
OddEven.OddEven()
# Out:
# Enter the Number to check, the given Number is Odd or Even : 12
# 12 is a Even Number

# %% [markdown]
# ## Create a Class and function that tells elegibility of marriage for male and female according to their age limit like 21 for male and 18 for female

# %%
class EligibilityForMarriage():
    def Eligibility():
        gender = input("Enter your Gender :").upper()
        age = int(input("Enter your Age :"))
        if (gender == "MALE" or gender == "M") and age >= 21:
            print("You are Eligible for Getting Married")
        elif (gender == "FEMALE" or gender == "F") and age >= 18:
            print("You are Eligible for Getting Married")
        else:
            print("Sorry, You are Not Eligible for Marriage")

EligibilityForMarriage.Eligibility()
# Out:
# Enter your Gender : m
# Enter your Age : 24
# You are Eligible for Getting Married

# %% [markdown]
# ## Class and Function - Calculate the percentage of your 10th marks

# %%
class FindPercentage():
    def percentage():
        print("Enter you 10th Marks to Caluclate your Percentage")
        tamil = int(input("TAMIL   :"))
        english = int(input("ENGLISH :"))
        maths = int(input("MATHS   :"))
        science = int(input("SCIENCE :"))
        social = int(input("SOCIAL  :"))
        total = tamil + english + maths + science + social
        percentage = total / 5
        print("Your Total is :",total)
        print("Your Percentage is :",percentage)
FindPercentage.percentage()
# Out:
# Enter you 10th Marks to Caluclate your Percentage
# TAMIL   : 92
# ENGLISH : 93
# MATHS   : 94
# SCIENCE : 95
# SOCIAL  : 96
# Your Total is : 470
# Your Percentage is : 94.0

# %% [markdown]
# ## Class and Function Print area and Perimeter of triangle using functions

# %%
class triangle():
    def area():
        height = int(input("Enter Height of the Triangle:"))
        breadth = int(input("Enter Breadth of the Triangle:"))
        area_calc = (height * breadth) / 2
        print("Area of Triangle:",area_calc)
    
    def perimeter():
        side_1 = int(input("Enter the Length od Side A:/n"))
        side_2 = int(input("Enter the Length od Side B:/n"))
        side_3 = int(input("Enter the Length od Side C:/n"))
        perimeter_calc = side_1 + side_2 + side_3
        print("Perimeter of Triangle:",perimeter_calc)

triangle.area()
triangle.perimeter()
# Out:
# Enter Height of the Triangle: 34
# Enter Breadth of the Triangle: 37
# Area of Triangle: 629.0
# Enter the Length od Side A:/n 5
# Enter the Length od Side B:/n 6
# Enter the Length od Side C:/n 5
# Perimeter of Triangle: 16
